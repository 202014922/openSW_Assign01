# %%
print("두 정수의 합과 차를 계산합니다.")
while True:
  try:
    a = int(input("첫 번째 정수를 입력하세요: "))
    b = int(input("두 번째 정수를 입력하세요: "))
    break

  except ValueError:
    print("정수를 입력해주세요.")

print("두 정수의 합:", a+b)
print("두 정수의 차:", a-b)
# Out:
# 첫 번째 정수를 입력하세요: 5
# 두 번째 정수를 입력하세요: 8
# 두 정수의 합: 13
# 두 정수의 차: -3
